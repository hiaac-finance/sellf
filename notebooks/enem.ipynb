# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pkl

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Loading and preprocessing ENEM dataset

# %%
# first create the "clean pool" of applicants
df = pd.read_csv("data/MICRODADOS_ENEM_2020.csv", encoding="cp860", sep=";")
df = df[df["SG_UF_PROVA"] == "SP"]

# drop rows with no NU_NOTA_LC
df = df.dropna(subset=["NU_NOTA_LC"])

# consider only 3 classes of age by removing individuals for higher class
df = df[df["TP_FAIXA_ETARIA"] <= 14]
df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"].apply(lambda x: (x - 1) // 7)
# df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"].apply(lambda x : min(x, 6))

# select applicants that are have TP_COR_RACA in [1, 2, 3]
df = df[df["TP_COR_RACA"].isin([1, 2, 3])]

df = df.sample(10_000, random_state=42)
# I will consider the score in portuguese test
df["target"] = df["NU_NOTA_LC"]
df["TP_DEPENDENCIA_ADM_ESC"] = df["TP_DEPENDENCIA_ADM_ESC"].fillna(-1)

# %%
columns_to_drop = [
    "NU_INSCRICAO",
    "NU_ANO",
    "CO_MUNICIPIO_ESC",
    "NO_MUNICIPIO_ESC",
    "CO_UF_ESC",
    "CO_MUNICIPIO_PROVA",
    "NO_MUNICIPIO_PROVA",
    "CO_UF_PROVA",
    "SG_UF_PROVA",
    "TP_PRESENCA_CN",
    "TP_PRESENCA_CH",
    "TP_PRESENCA_LC",
    "TP_PRESENCA_MT",
    "CO_PROVA_CN",
    "CO_PROVA_CH",
    "CO_PROVA_LC",
    "CO_PROVA_MT",
    "NU_NOTA_CN",
    "NU_NOTA_CH",
    "NU_NOTA_LC",
    "NU_NOTA_MT",
    "TX_RESPOSTAS_CN",
    "TX_RESPOSTAS_CH",
    "TX_RESPOSTAS_LC",
    "TX_RESPOSTAS_MT",
    "TX_GABARITO_CN",
    "TX_GABARITO_CH",
    "TX_GABARITO_LC",
    "TX_GABARITO_MT",
    "TP_STATUS_REDACAO",
    "NU_NOTA_COMP1",
    "NU_NOTA_COMP2",
    "NU_NOTA_COMP3",
    "NU_NOTA_COMP4",
    "NU_NOTA_COMP5",
    "NU_NOTA_REDACAO",
    "TP_NACIONALIDADE",
    "SG_UF_ESC",
]

# %%
df = df.drop(columns=columns_to_drop)
print(f"Remaining columns: {df.columns.tolist()}")
for col in ["TP_LOCALIZACAO_ESC", "TP_SIT_FUNC_ESC", "TP_ENSINO"]:
    df[col] = df[col].fillna("Unknown")

df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"] - 1

# convert all columns to str
df["TP_COR_RACA"] = df["TP_COR_RACA"].apply(lambda x: x == 1)
for col in df.columns:
    df[col] = df[col].apply(str)
df["target"] = df["target"].astype(float)

# make first column be "TP_COR_RACA" followed by "TP_FAIXA_ETARIA"
remaining_columns = [
    col for col in df.columns if col not in ["TP_COR_RACA", "TP_FAIXA_ETARIA"]
]
df = df[["TP_COR_RACA", "TP_FAIXA_ETARIA"] + remaining_columns]
df["target"] = df["target"].apply(lambda x: 1 if x > 575 else 0)
# Out:
# Remaining columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'TP_LINGUA', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'target']

# %% [markdown]
# ## Transform all columns in numerical

# %%
Z = df["TP_COR_RACA"].apply(lambda x: 1.0 if x == "True" else 0.0).values
X_age = df["TP_FAIXA_ETARIA"].apply(lambda x: int(x))
X = df.drop(columns=["target", "TP_COR_RACA", "TP_FAIXA_ETARIA"])
y = df["target"]

print("Positive rate:", np.mean(y))
# Out:
# Positive rate: 0.3799

# %%
one_hot = OneHotEncoder(sparse_output=False)
X_age = one_hot.fit_transform(X_age.values.reshape(-1, 1))
one_hot = OneHotEncoder(
    sparse_output=False, handle_unknown="infrequent_if_exist", min_frequency=0.1
)
X = one_hot.fit_transform(X)

# %%
# create columns that are the interaction of Z and X_age
nc = X_age.shape[1]
X_interaction = np.zeros((X_age.shape[0], 2 * nc))

# The first nc columns are related to Z = 0 and the second nc columns are related to Z = 1

for i in range(X_age.shape[0]):
    z = Z[i]
    if z == 0:
        X_interaction[i, :nc] = X_age[i, :]
    else:
        X_interaction[i, nc:] = X_age[i, :]

# %% [markdown]
# ## Fit a model that simulates $\alpha(x, z)$

# %%
X_data = np.concatenate([Z.reshape(-1, 1), X_interaction, X], axis=1)
model = LogisticRegression(
    max_iter=1000, random_state=42
)  # , class_weight={0:1, 1: 2})

X_train, X_test, y_train, y_test, z_train, z_test = train_test_split(
    X_data, y, Z, test_size=0.2, random_state=42
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(f"Positive rate in predictions: {np.mean(y_pred):.2f}")
# Out:
# Accuracy: 0.69
# Positive rate in predictions: 0.30

# %%
for i in range(2):
    print(f"Group {i} probability:\t {np.mean(Z == i):.2f}")
    print(
        f"Group {i} accuracy:\t {accuracy_score(y_test[z_test == i], y_pred[z_test == i]):.2f}"
    )
    print(f"Group {i} positive rate:\t {np.mean(y_pred[z_test == i]):.2f}")
    print("")
# Out:
# Group 0 probability:	 0.38
# Group 0 accuracy:	 0.75
# Group 0 positive rate:	 0.12
#
# Group 1 probability:	 0.62
# Group 1 accuracy:	 0.66
# Group 1 positive rate:	 0.42

# %% [markdown]
# ## Visualize model

# %%
# bar plot of target grouped by "TP_COR_RACA"

group_labels = ["Black/Pardo", "White"]

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(11, 3.5))

plt.suptitle("Distribution of age and score based on (ENEM)")

for i in range(2):
    group_counts = X_interaction[:, (nc * i) : (nc * (i + 1))]
    group_counts = np.sum(group_counts, axis=0) / (Z == i).sum()
    axs[0].plot(group_counts, linestyle="--", marker="o", label=group_labels[i])


axs[0].set_ylabel("P(Age| Z)")


for i in range(2):
    p_y = np.zeros(nc)
    for c in range(nc):
        p_y[c] = np.mean(y[(Z == i) & (X_age[:, c] == 1)])

    axs[1].plot(p_y, linestyle="--", marker="o", label=group_labels[i])

axs[1].set_ylabel("P(Y = 1 | Age, Z)")
axs[1].set_title("Distribution of Y based on the dataset")


predictions = model.predict_proba(X_data)[:, 1]

# calculate predictions per group and age
for i in range(2):
    p_y = np.zeros(nc)
    for c in range(nc):
        p_y[c] = np.mean(predictions[(Z == i) & (X_age[:, c] == 1)])

    axs[2].plot(p_y, linestyle="--", marker="o", label=group_labels[i])

# coef_groups = model.coef_[0][3:2*nc+3].reshape(2, nc)

# for i in range(2):
#    axs[2].plot(coef_groups[i], label=f"Group {i}", linestyle='--', marker="o")


for i in range(3):
    axs[i].set_xlabel("Age group")
    axs[i].legend()

axs[0].set_title("Distribution of age groups")
axs[2].set_ylabel("$P(\hat Y = 1 | \text{Age}, Z)$")
axs[2].set_title("Distribution of Y based on the model")

for i in range(3):
    axs[i].grid()
    axs[i].set_xticks(range(nc))
plt.tight_layout()
plt.savefig("figures/enem.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Save the pool and model on disk

# %%
pool = []

for i in range(X_data.shape[0]):
    features = np.concatenate([X_data[i], [0]]).astype(np.float32)
    pool.append(
        {
            "features": features,
            "group": Z[i],
        }
    )

print(f"Features shape: {features.shape}")
with open("data/enem_pool.pkl", "wb") as f:
    pkl.dump(pool, f)

with open("data/enem_model.pkl", "wb") as f:
    pkl.dump(model, f)
# Out:
# Features shape: (126,)

# %% [markdown]
# ## Loading for second version

# %%
# first create the "clean pool" of applicants
df = pd.read_csv("data/MICRODADOS_ENEM_2020.csv", encoding="cp860", sep=";")

df = df[df["SG_UF_PROVA"] == "SP"]

# drop rows with no NU_NOTA_LC
df = df.dropna(subset=["NU_NOTA_LC"])

# consider only 3 classes of age by removing individuals for higher class
df = df[df["TP_FAIXA_ETARIA"] <= 14]
df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"].apply(lambda x: (x - 1) // 7)
# df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"].apply(lambda x : min(x, 6))

# select applicants that are have TP_COR_RACA in [1, 2, 3]
df = df[df["TP_COR_RACA"].isin([1, 2, 3])]

# %%
df = df.sample(10_000, random_state=42)
# I will consider the score in portuguese test
df["target"] = df["NU_NOTA_LC"]
df["TP_DEPENDENCIA_ADM_ESC"] = df["TP_DEPENDENCIA_ADM_ESC"].fillna(-1)

# %%
columns_to_drop = [
    "NU_INSCRICAO",
    "NU_ANO",
    "CO_MUNICIPIO_ESC",
    "NO_MUNICIPIO_ESC",
    "CO_UF_ESC",
    "CO_MUNICIPIO_PROVA",
    "NO_MUNICIPIO_PROVA",
    "CO_UF_PROVA",
    "SG_UF_PROVA",
    "TP_PRESENCA_CN",
    "TP_PRESENCA_CH",
    "TP_PRESENCA_LC",
    "TP_PRESENCA_MT",
    "CO_PROVA_CN",
    "CO_PROVA_CH",
    "CO_PROVA_LC",
    "CO_PROVA_MT",
    # Let keep the grades
    #'NU_NOTA_CN',
    #'NU_NOTA_CH',
    "NU_NOTA_LC",
    #'NU_NOTA_MT',
    "TX_RESPOSTAS_CN",
    "TX_RESPOSTAS_CH",
    "TX_RESPOSTAS_LC",
    "TX_RESPOSTAS_MT",
    "TX_GABARITO_CN",
    "TX_GABARITO_CH",
    "TX_GABARITO_LC",
    "TX_GABARITO_MT",
    "TP_STATUS_REDACAO",
    "NU_NOTA_COMP1",
    "NU_NOTA_COMP2",
    "NU_NOTA_COMP3",
    "NU_NOTA_COMP4",
    "NU_NOTA_COMP5",
    "NU_NOTA_REDACAO",
    "TP_NACIONALIDADE",
    "SG_UF_ESC",
]

# %%
df = df.drop(columns=columns_to_drop)
print(f"Remaining columns: {df.columns.tolist()}")
for col in ["TP_LOCALIZACAO_ESC", "TP_SIT_FUNC_ESC", "TP_ENSINO"]:
    df[col] = df[col].fillna("Unknown")

for col in ["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]:
    df[col] = df[col].fillna(df[col].mean())

df["TP_FAIXA_ETARIA"] = df["TP_FAIXA_ETARIA"] - 1

# convert all columns to str
df["TP_COR_RACA"] = df["TP_COR_RACA"].apply(lambda x: x == 1)
columns_to_str = [col for col in df.columns]
columns_to_str.remove("NU_NOTA_CN")
columns_to_str.remove("NU_NOTA_CH")
columns_to_str.remove("NU_NOTA_MT")
for col in columns_to_str:
    df[col] = df[col].apply(str)
df["target"] = df["target"].astype(float)

# make first column be "TP_COR_RACA" followed by "TP_FAIXA_ETARIA"
remaining_columns = [
    col for col in df.columns if col not in ["TP_COR_RACA", "TP_FAIXA_ETARIA"]
]
df = df[["TP_COR_RACA", "TP_FAIXA_ETARIA"] + remaining_columns]
df["target"] = df["target"].apply(lambda x: 1 if x > 575 else 0)
# Out:
# Remaining columns: ['TP_FAIXA_ETARIA', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'TP_LINGUA', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'target']

# %%
Z = df["TP_COR_RACA"].apply(lambda x: 1.0 if x == "True" else 0.0).values
X_age = df["TP_FAIXA_ETARIA"].apply(lambda x: int(x))
X = df.drop(columns=["target", "TP_COR_RACA", "TP_FAIXA_ETARIA"])
y = df["target"]

print("Positive rate:", np.mean(y))
# Out:
# Positive rate: 0.3825

# %%
columns_to_one_hot = [col for col in X.columns]
columns_to_one_hot.remove("NU_NOTA_CN")
columns_to_one_hot.remove("NU_NOTA_CH")
columns_to_one_hot.remove("NU_NOTA_MT")

# %%
one_hot = OneHotEncoder(sparse_output=False)
X_age = one_hot.fit_transform(X_age.values.reshape(-1, 1))
one_hot = OneHotEncoder(
    sparse_output=False, handle_unknown="infrequent_if_exist", min_frequency=0.1
)
# onehot encode only "columns_to_str"
X_one_hot = one_hot.fit_transform(X[columns_to_one_hot])
scaling = StandardScaler()
X_scaled = scaling.fit_transform(X[["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_MT"]])

# %%
X = np.concatenate([X_one_hot, X_scaled], axis=1)

# %%
# create columns that are the interaction of Z and X_age
nc = X_age.shape[1]
X_interaction = np.zeros((X_age.shape[0], 2 * nc))

# The first nc columns are related to Z = 0 and the second nc columns are related to Z = 1

for i in range(X_age.shape[0]):
    z = Z[i]
    if z == 0:
        X_interaction[i, :nc] = X_age[i, :]
    else:
        X_interaction[i, nc:] = X_age[i, :]

# %% [markdown]
# Fit $\alpha(x, z)$

# %%
X_data = np.concatenate([Z.reshape(-1, 1), X_age, X], axis=1)
model = LogisticRegression(
    max_iter=1000, random_state=42
)  # , class_weight={0:1, 1: 2})

X_train, X_test, y_train, y_test, z_train, z_test = train_test_split(
    X_data, y, Z, test_size=0.2, random_state=42
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(f"Positive rate in predictions: {np.mean(y_pred):.2f}")
# Out:
# Accuracy: 0.81
# Positive rate in predictions: 0.37

# %%
for i in range(2):
    print(f"Group {i} probability:\t {np.mean(Z == i):.2f}")
    print(
        f"Group {i} accuracy:\t {accuracy_score(y_test[z_test == i], y_pred[z_test == i]):.2f}"
    )
    print(f"Group {i} positive rate:\t {np.mean(y_pred[z_test == i]):.2f}")
    print("")
# Out:
# Group 0 probability:	 0.41
# Group 0 accuracy:	 0.81
# Group 0 positive rate:	 0.25
#
# Group 1 probability:	 0.59
# Group 1 accuracy:	 0.81
# Group 1 positive rate:	 0.46

# %%
# bar plot of target grouped by "TP_COR_RACA"

group_labels = ["Black/Pardo", "White"]

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(11, 3.5))

plt.suptitle("Distribution of age and score based on (ENEM)")

for i in range(2):
    group_counts = X_interaction[:, (nc * i) : (nc * (i + 1))]
    group_counts = np.sum(group_counts, axis=0) / (Z == i).sum()
    axs[0].plot(group_counts, linestyle="--", marker="o", label=group_labels[i])


axs[0].set_ylabel("P(Age| Z)")


for i in range(2):
    p_y = np.zeros(nc)
    for c in range(nc):
        p_y[c] = np.mean(y[(Z == i) & (X_age[:, c] == 1)])

    axs[1].plot(p_y, linestyle="--", marker="o", label=group_labels[i])

axs[1].set_ylabel("P(Y = 1 | Age, Z)")
axs[1].set_title("Distribution of Y based on the dataset")


predictions = model.predict_proba(X_data)[:, 1]

# calculate predictions per group and age
for i in range(2):
    p_y = np.zeros(nc)
    for c in range(nc):
        p_y[c] = np.mean(predictions[(Z == i) & (X_age[:, c] == 1)])

    axs[2].plot(p_y, linestyle="--", marker="o", label=group_labels[i])

# coef_groups = model.coef_[0][3:2*nc+3].reshape(2, nc)

# for i in range(2):
#    axs[2].plot(coef_groups[i], label=f"Group {i}", linestyle='--', marker="o")


for i in range(3):
    axs[i].set_xlabel("Age group")
    axs[i].legend()

axs[0].set_title("Distribution of age groups")
axs[2].set_ylabel("$P(\hat Y = 1 | \text{Age}, Z)$")
axs[2].set_title("Distribution of Y based on the model")

for i in range(3):
    axs[i].grid()
    axs[i].set_xticks(range(nc))
plt.tight_layout()
#plt.savefig("figures/enem.pdf", bbox_inches="tight")
plt.show()

# %%
pool = []

for i in range(X_data.shape[0]):
    features = np.concatenate([X_data[i], [0]]).astype(np.float32)
    pool.append(
        {
            "features": features,
            "group": Z[i],
        }
    )

print(f"Features shape: {features.shape}")

with open("data/enemc_pool.pkl", "wb") as f:
    pkl.dump(pool, f)

with open("data/enemc_model.pkl", "wb") as f:
    pkl.dump(model, f)
# Out:
# Features shape: (129,)
