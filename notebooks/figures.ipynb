# %%
import pandas as pd
import numpy as np
from glob import glob
from omegaconf import OmegaConf
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
# use the seaborn whitegrid style
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# # Helper function

# %%
def summarize_hyperparam(env, mu_type, alg_names):
    def summ_ep(df):
        delta = df.delta.abs().mean()
        delta_obs = df.delta_obs.abs().mean()
        rew = df.sort_values("t")["resource"].values[-1]
        accept_g0 = df[df.group_id == 0].action.mean()
        accept_g1 = df[df.group_id == 1].action.mean()
        return pd.Series(
            {
                "delta": delta,
                "delta_last": df.sort_values("t")["delta"].values[-1],
                "delta_obs": delta_obs,
                "reward": rew,
                "accept_g0": accept_g0,
                "accept_g1": accept_g1,
            }
        )

    files = [
        f"experiments/{env}/{mu_type}/{alg}/eval/eval_data.csv" for alg in alg_names
    ]
    results = []
    for file in files:
        try:
            alg = file.split("/")[-3]
            df = pd.read_csv(file)
            # check if there is any delta_obs negative, and print alg if so
            if (df.delta_obs < 0).any():
                print(f"Negative delta_obs found in {alg}")
            df = df.groupby("ep").apply(summ_ep).aggregate(["mean", "std"])
            alg_simplified = alg.split("(")[0]#alg.replace("sellf_hard", "sellf").split("_")[0]
            results.append(
                {
                    "alg": alg,
                    "alg_simplified": alg_simplified,
                    "delta": df["delta"]["mean"],
                    "delta_std": df["delta"]["std"],
                    "reward": df["reward"]["mean"],
                    "reward_std": df["reward"]["std"],
                    "delta_obs": df["delta_obs"]["mean"],
                    "delta_obs_std": df["delta_obs"]["std"],
                    "accept_g0": df["accept_g0"]["mean"],
                    "accept_g1": df["accept_g1"]["mean"],
                    "delta_last": df["delta_last"]["mean"],
                }
            )
        except:
            continue
    results = pd.DataFrame(results)

    def evaluate(df):
        deltas = df["delta_obs"].values.copy()
        rewards = df["reward"].values.copy()

        # round delta to 2 decimal places
        deltas = np.round(deltas, 2)
        deltas[deltas <= 0.05] = 0

        delta_min = deltas.min()
        rewards[deltas > delta_min] = 0

        df["score"] = rewards

        return df

    results = results.groupby("alg_simplified", group_keys = False).apply(evaluate).reset_index()
    return results

# %%
def base_legend_func(alg_name):
    alg_name = alg_name.split("(")[0]
    if alg_name == "sellf":
        return "SELLF"
    if alg_name == "sellf_deep":
        return "SELLF (ReLU NN)"
    if alg_name == "sellf_censored_25":
        return "SELLF (Semi-stoc.)"
    if alg_name == "pocar_full" or alg_name == "pocar_full_v2":
        return "POCAR (Oracle)"
    if alg_name == "pocar":
        return "POCAR"
    if alg_name == "ppo":
        return "PPO"
    if alg_name == "elbert":
        return "ELBERT"
    if alg_name == "focops":
        return "FOCOPS"
    return alg_name

def base_color_func(alg_name):
    if "sellf_deep" in alg_name:
        return "#984ea3"
    if "sellf_censored" in alg_name:
        return "#7570b3"
    if "sellf" in alg_name:
        return "#e78ac3"
    if "full" in alg_name:
        return "#fc8d62"
    if "ppo" in alg_name:
        return "#8da0cb"
    if "pocar" in alg_name:
        return "#a6d854"
    if "elbert" in alg_name:
        return "#1d9871"
    if "focops" in alg_name:
        return "#e5c494"

# %%
def get_alg_names(alg_name):
    config = OmegaConf.load(f"configs/{alg_name}.yaml")
    alg_names = []
    for params in config.algorithm_param_list:
        params_info = " ".join([f"{k}:{v}" for k, v in params.items()])
        alg_names.append(f"{alg_name}({params_info})")
    
    if len(alg_names) == 0:
        alg_names.append(f"{alg_name}()")
    return alg_names

# %%
def get_zorder(alg_name):
    if "sellf_censored" in alg_name:
        return 2
    elif "sellf" in alg_name:
        return 3

    return 1

# %%
def base_plot(selected_algs, env_name, mu_type, save_path):
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(8, 3))

    df_list = [
        pd.read_csv(f"experiments/{env_name}/{mu_type}/{alg}/eval/eval_data.csv")
        for alg in selected_algs
    ]

    for i in range(len(df_list)):
        df_list[i]["accept_g0"] = df_list[i]["action"] * (df_list[i]["group_id"] == 0)
        df_list[i]["accept_g1"] = df_list[i]["action"] * (df_list[i]["group_id"] == 1)

        # for each ep, compute cumulative sum of accept_g0 and accept_g1
        df_list[i]["n_accept_g0"] = df_list[i].groupby("ep")["accept_g0"].cumsum()
        df_list[i]["n_accept_g1"] = df_list[i].groupby("ep")["accept_g1"].cumsum()

        df_list[i]["delta"] = df_list[i]["delta"].abs()

        df_list[i] = (
            df_list[i]
            .groupby("t")
            .agg(
                {
                    "resource": ["mean", "std"],
                    "delta": ["mean", "std"],
                    "n_accept_g0": ["mean", "std"],
                    "n_accept_g1": ["mean", "std"],
                }
            )
        )

    def get_zorder(alg_name):
        if "sellf_censored" in alg_name:
            return 2
        elif "sellf" in alg_name:
            return 3
        return 1
    
    for alg, df in zip(selected_algs, df_list):
        axs[0].plot(
            df.index,
            df["resource"]["mean"],
            label=base_legend_func(alg),
            color=base_color_func(alg),
            linestyle="--" if "full" in alg else "-",
            zorder=get_zorder(alg),
        )
        axs[0].fill_between(
            df.index,
            df["resource"]["mean"] - df["resource"]["std"],
            df["resource"]["mean"] + df["resource"]["std"],
            alpha=0.3,
            color=base_color_func(alg),
            zorder=get_zorder(alg),
        )

        axs[1].plot(
            df.index,
            df["delta"]["mean"],
            label=base_legend_func(alg),
            color=base_color_func(alg),
            linestyle="--" if "full" in alg else "-",
            zorder=get_zorder(alg),
        )
        axs[1].fill_between(
            df.index,
            df["delta"]["mean"] - df["delta"]["std"],
            df["delta"]["mean"] + df["delta"]["std"],
            alpha=0.3,
            color=base_color_func(alg),
            zorder=get_zorder(alg),
        )

        #diff_accept = df["n_accept_g0"]["mean"]
        #axs[2].plot(
        #    df.index,
        #    diff_accept,
        #    label=base_legend_func(alg),
        #    color=base_color_func(alg),
        #    linestyle="--" if "full" in alg else "-",
        #    lw=2,
        #)

    for i in range(2):
        axs[i].set_xlabel("Timestep")

    axs[0].set_title("Cumulative Reward", fontsize = 12)
    axs[1].set_title("Disparity ($|\Delta_t|$)", fontsize = 12)
    #axs[2].set_title("Nº of acceptances for\nunderprivileged group")

    # place legend outside bellow all plots
    fig.subplots_adjust(bottom=0.3, wspace=0.33)

    axs[1].legend(
        loc="upper center",
        bbox_to_anchor=(-0.2, -0.2),
        ncol=4 #len(selected_algs),
    )

    for i in range(2):
        axs[i].grid(True)
    plt.savefig(save_path, bbox_inches="tight")
    plt.show()

# %%
def process_table(result_table):
    table = result_table[["alg_simplified", "delta", "delta_std", "reward", "reward_std"]].copy()
    # round 2 decimal places
    table["delta"] = table["delta"].round(2)
    table["delta_std"] = table["delta_std"].round(2)
    table["reward"] = table["reward"].round(2)
    table["reward_std"] = table["reward_std"].round(1)

    print("alg \t\t\t delta \t\t\t reward")
    def alg_order(alg_name):
        if "ppo" in alg_name:
            return 0
        if "pocar_full" in alg_name:
            return 2
        if "pocar" in alg_name:
            return 1
        if "sellf" in alg_name:
            return 3
        return 4

    table["order"] = table["alg_simplified"].apply(alg_order)
    table = table.sort_values(by=["order", "alg_simplified"])
    for i, row in table.iterrows():
        skip = "\t\t\t" if len(base_legend_func(row['alg_simplified'])) <= 5 else "\t\t"
        print(f"{base_legend_func(row['alg_simplified'])} {skip} & {row['delta']} ($\pm$ {row['delta_std']}) \t & {row['reward']} ($\pm$ {row['reward_std']})")

# %% [markdown]
# # Ablation

# %%
env_name = "fico_equal"
mu_type = "accuracy"
train_files = glob(f"experiments/ablation_old/**/{env_name}/{mu_type}/**/models/*.csv")
eval_files = glob(f"experiments/ablation_old/**/{env_name}/{mu_type}/**/eval/*.csv")
alg_dict = dict([(f.split("/")[-3], []) for f in train_files])
alg_dict_eval = dict([(f.split("/")[-3], []) for f in eval_files])
for f in train_files:
    alg_name = f.split("/")[-3]
    alg_dict[alg_name].append(f)
for f in eval_files:
    alg_name = f.split("/")[-3]
    alg_dict_eval[alg_name].append(f)

# %%
### sumarize learning metrics

alg_dfs = {}

for alg_name, file_list in alg_dict.items():
    df_list = []
    for f in file_list:
        df = pd.read_csv(f)
        df["t"] = np.arange(len(df))
        df_list.append(df)
    df = pd.concat(df_list)
    df["delta_diff"] = (df["delta"] - df["delta_obs"])
    df["term_g0"] =(1 - df["accept_g0"]) * df["renyi_div_g0"]
    df["term_g1"] =(1 - df["accept_g1"]) * df["renyi_div_g1"]
    df["term"] = df["term_g0"] + df["term_g1"]

    # apply moving average with window size 10 for every numeric column
    for col in ["reward", "delta", "delta_obs", "delta_diff"]:
        df[col] = df[col].rolling(window=1).mean()

    df = df.groupby("t").agg({
        "reward": ["mean", "std"],
        "delta": ["mean", "std"],
        "delta_obs": ["mean", "std"],
        "delta_diff": ["mean", "std"],
        "term": ["mean", "std"],
        "accept_g0": ["mean", "std"],
        "accept_g1": ["mean", "std"],
        "max_weight_g0" : ["mean", "std"],
        "max_weight_g1" : ["mean", "std"],
        "aK_min_g0" : ["mean", "std"],
        "aK_min_g1" : ["mean", "std"],
    })
    alg_dfs[alg_name] = df

# %%
alg_dfs_eval = {}
for alg_name, file_list in alg_dict_eval.items():
    df_list = []
    for f in file_list:
        df = pd.read_csv(f)
        df["t"] = np.arange(len(df))
        df_list.append(df)
    df = pd.concat(df_list)
    df["delta"] = df["delta"].abs()
    df = df.groupby("t").agg({"delta" : "mean"})
    alg_dfs_eval[alg_name] = {
        "mean" : df["delta"].mean(),
        "std" : df["delta"].std()
    }

# %%
sorted_algs = sorted(alg_dfs, key = lambda x : float(x.split(":")[2].replace(")", "")))

# %%
colors = ['#c7e9b4','#7fcdbb','#41b6c4','#2c7fb8','#253494']

def color_func(alg_name):
    idx = sorted_algs.index(alg_name)
    return colors[idx]

def legend_func(alg_name):
    return alg_name.split(" ")[-1].replace(")", "").replace("beta_2:", "$\\beta_2=$") 


fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(7.5, 3), gridspec_kw={'width_ratios': [1, 1, 0.7]})


for alg_name in sorted_algs:
    df = alg_dfs[alg_name]
    axs[0].plot(
        df["delta_diff"]["mean"],
        label=(alg_name),
        color=color_func(alg_name),
        lw = 2,
    )

    axs[0].fill_between(
        df.index,
        df["delta_diff"]["mean"] - df["delta_diff"]["std"],
        df["delta_diff"]["mean"] + df["delta_diff"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )

    axs[0].axhline(0, color="black", linestyle="--", linewidth=1, alpha=0.3)


    axs[1].plot(
        df["term"]["mean"],
        label=legend_func(alg_name),
        color=color_func(alg_name), 
        lw = 2,
    )

    axs[1].fill_between(
        df.index,
        df["term"]["mean"] - df["term"]["std"],
        df["term"]["mean"] + df["term"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )

    axs[1].axhline(0, color="black", linestyle="--", linewidth=1, alpha=0.3)


    df = alg_dfs_eval[alg_name]
    axs[2].bar(
        alg_name,
        df["mean"],
        yerr=df["std"],
        color=color_func(alg_name),
    )
    axs[2].set_xticks(range(len(sorted_algs)))
    axs[2].set_xticklabels(
        ["" for s in sorted_algs],
        #[s.split(" ")[-1].replace(")", "").replace("beta_2:", "$\\beta_2=$") for s in sorted_algs],
        rotation=45,
    )
    #plt.show()

axs[0].set_ylim(-0.01, 0.03)
axs[1].set_ylim(0, 5)
axs[0].set_title(r"$\Delta_t - \tilde \Delta_t $", fontsize=16)
axs[1].set_title(r"$\Sigma_i r^i \mathbb{E}[\mathrm{w}(x, i)^2]$", fontsize=16)
axs[2].set_title(r"$|\Delta_t|$", fontsize=16)

fig.subplots_adjust(bottom=0.3, wspace=0.33)

axs[0].set_xlabel("Learning iteration", fontsize = 14)
axs[1].set_xlabel("Learning iteration", fontsize = 14)
axs[2].set_xlabel(r"$\beta_2$", fontsize = 14)
axs[1].legend(
    loc="upper center",
    bbox_to_anchor=(0.35, -0.3),
    ncol=5,
    fontsize=14,
    columnspacing=0.5,
)

for i in range(3):
    axs[i].grid(True)

# make the last only be horizontal grid
axs[-1].xaxis.grid(False)

# reduce the horizontal gap between plots


# place y ticks of last plot on the right
axs[2].yaxis.tick_right()
axs[2].yaxis.set_label_position("right")

fig.subplots_adjust(wspace=0.15)

plt.savefig("figures/ablation_beta2.pdf", bbox_inches="tight")

# %% [markdown]
# ### Ablation of $\beta_1$

# %%
env_name = "fico_equal"
mu_type = "tpr"
eval_files = glob(f"experiments/ablation_2/0/{env_name}/{mu_type}/**/eval/*.csv")
alg_dict_eval = dict([(f.split("/")[-3], []) for f in eval_files])
for f in eval_files:
    alg_name = f.split("/")[-3]
    alg_dict_eval[alg_name].append(f)

alg_dfs_eval = {}
for alg_name, file_list in alg_dict_eval.items():
    df_list = []
    for f in file_list:
        df = pd.read_csv(f)
        # df["t"] = np.arange(len(df))
        df_list.append(df)
    df = pd.concat(df_list)
    df["delta"] = df["delta"].abs()
    df["delta_obs"] = df["delta_obs"].abs()

    df = df.groupby("t").agg({"delta": "mean", "resource": ["mean", "std"], "delta_obs": "mean"})
    beta_1 = alg_name.split(" ")[0].split(":")[1]
    alg_dfs_eval[beta_1] = {
        "delta_mean": df["delta"]["mean"].mean(),
        "delta_std": df["delta"]["mean"].std(),
        "resource_mean": df["resource"]["mean"].iloc[-1],
        "resource_std": df["resource"]["std"].iloc[-1],
        "delta_obs_mean": df["delta_obs"]["mean"].mean(),
        "delta_obs_std": df["delta_obs"]["mean"].std(),
    }

# %%
fig, axs = plt.subplots(figsize=(5, 2.5), nrows=1, ncols=2, sharey=True)

colors = ["#c7e9b4", "#7fcdbb", "#41b6c4", "#1d91c0", "#225ea8", "#0c2c84"]
beta_1_list = [1, 2, 3, 4, 5, 10]

for j, beta_1 in enumerate(beta_1_list):
    df = alg_dfs_eval[str(beta_1)]
    for i, col in enumerate(["delta_obs", "delta"]):
        axs[i].scatter(
            df["resource_mean"], df[f"{col}_mean"], label=beta_1, color=colors[j]
        )
        # display y error bars
        axs[i].errorbar(
            df["resource_mean"],
            df[f"{col}_mean"],
            xerr=df["resource_std"],
            yerr=df[f"{col}_std"],
            fmt="none",
            ecolor="gray",
            alpha=0.8,
        )
axs[0].set_xlabel("Reward", fontsize=14)
axs[0].set_ylabel("$|\\tilde \\Delta_t|$", fontsize=14)
axs[1].legend(
    title=r"$\beta_1$", loc="upper left", bbox_to_anchor=(1.02, 1.0), fontsize=12, title_fontsize=14
)
axs[1].set_xlabel("Reward", fontsize=14)
axs[1].set_ylabel("$|\\Delta_t|$", fontsize=14)
plt.savefig("figures/ablation_beta1.pdf", bbox_inches="tight")

# %% [markdown]
# ### Analysis of weights

# %%
colors = ['#c7e9b4','#7fcdbb','#41b6c4','#2c7fb8','#253494']

def color_func(alg_name):
    idx = sorted_algs.index(alg_name)
    return colors[idx]

def legend_func(alg_name):
    return alg_name.split(" ")[-1].replace(")", "").replace("beta_2:", "$\\beta_2=$")  


fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))


for alg_name in sorted_algs:
    df = alg_dfs[alg_name]

    # first plot the weights
    axs[0].plot(
        df["max_weight_g0"]["mean"],
        label=legend_func(alg_name),
        color=color_func(alg_name),
        lw = 2,
    )

    axs[0].fill_between(
        df.index,
        df["max_weight_g0"]["mean"] - df["max_weight_g0"]["std"],
        df["max_weight_g0"]["mean"] + df["max_weight_g0"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )

    axs[1].plot(
        df["max_weight_g1"]["mean"],
        label=legend_func(alg_name),
        color=color_func(alg_name),
        lw = 2,
    )

    axs[1].fill_between(
        df.index,
        df["max_weight_g1"]["mean"] - df["max_weight_g1"]["std"],
        df["max_weight_g1"]["mean"] + df["max_weight_g1"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )

    # now, plot the denominators
    axs[2].plot(
        df["aK_min_g0"]["mean"],
        label=legend_func(alg_name),
        color=color_func(alg_name),
        lw = 2,
    )

    axs[2].fill_between(
        df.index,
        df["aK_min_g0"]["mean"] - df["aK_min_g0"]["std"],
        df["aK_min_g0"]["mean"] + df["aK_min_g0"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )

    axs[3].plot(
        df["aK_min_g1"]["mean"],
        label=legend_func(alg_name),
        color=color_func(alg_name),
        lw = 2,
    )

    axs[3].fill_between(
        df.index,
        df["aK_min_g1"]["mean"] - df["aK_min_g1"]["std"],
        df["aK_min_g1"]["mean"] + df["aK_min_g1"]["std"],
        alpha=0.2,
        color = color_func(alg_name),
    )


#axs[0].set_ylim(-0.01, 0.03)
#axs[1].set_ylim(0, 5)
axs[0].set_title(r"$\max_x \{\mathrm{w}(x, 0)\}$")
axs[1].set_title(r"$\max_x \{\mathrm{w}(x, 1)\}$")
axs[2].set_title(r"$\min_x P(A[1:K] = 1 |x,0)$")
axs[3].set_title(r"$\min_X P(A[1:K] = 1 | x, 1)$")
#axs[2].set_title(r"$|\Delta_t|$")
#
#fig.subplots_adjust(bottom=0.3, wspace=0.33)
#
#axs[0].set_xlabel("Learning iteration")
#axs[1].set_xlabel("Learning iteration")
#axs[2].set_xlabel(r"$\beta_2$")
axs[1].legend(
    loc="upper center",
    bbox_to_anchor=(0.8, -0.1),
    ncol=5,
)

for i in range(4):
   axs[i].grid(True)

#axs[2].set_xlim(0, 30)
#axs[3].set_xlim(0, 30)


plt.savefig("figures/ablation_weights.pdf", bbox_inches="tight")

# %% [markdown]
# # Bound

# %%
env_name = "fico_equal"
mu_type = "accuracy"
train_files = glob(f"experiments/bound/**/{env_name}/{mu_type}/**/models/*.csv")
alg_dict = dict([(f.split("/")[-3], []) for f in train_files])
for f in train_files:
    alg_name = f.split("/")[-3]
    alg_dict[alg_name].append(f)


alg_dfs = {}

for alg_name, file_list in alg_dict.items():
    df_list = []
    for f in file_list:
        df = pd.read_csv(f)
        df["t"] = np.arange(len(df))
        df_list.append(df)
    df = pd.concat(df_list)
    df["delta_diff"] = (df["delta"] - df["delta_obs"])
    df["renyi_div_g0"] = df["renyi_div_g0"].fillna(0)
    df["renyi_div_g1"] = df["renyi_div_g1"].fillna(0)
    df["error_accepted_g0"] = df["error_accepted_g0"].fillna(0)
    df["error_accepted_g1"] = df["error_accepted_g1"].fillna(0)

    df = df.groupby("t").agg({
        "reward": ["mean", "std"],
        "delta": ["mean", "std"],
        "delta_obs": ["mean", "std"],
        "delta_diff": ["mean", "std"],
        "renyi_div_g0": ["mean", "std"],
        "renyi_div_g1": ["mean", "std"],
        "error_accepted_g0": ["mean", "std"],
        "error_accepted_g1": ["mean", "std"],
    })
    alg_dfs[alg_name] = df

sorted_algs = sorted(alg_dfs, key = lambda x : float(x.split(":")[2].replace(")", "")))

# %%
colors = ['#c7e9b4','#7fcdbb','#41b6c4','#2c7fb8','#253494']

def color_func(alg_name):
    idx = sorted_algs.index(alg_name)
    return colors[idx]

def legend_func(alg_name):
    return alg_name.split(" ")[-1].replace(")", "").replace("beta_2:", "$\\beta_2=$") 


fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9, 7), sharex=True, sharey="row")


for alg_name in sorted_algs:
    df = alg_dfs[alg_name]

    for g in range(2):
        axs[0, g].plot(
            df[f"error_accepted_g{g}"]["mean"],
            label=legend_func(alg_name),
            color=color_func(alg_name), 
            lw = 2,
        )   

        axs[1, g].plot(
            df[f"renyi_div_g{g}"]["mean"],
            label=legend_func(alg_name),
            color=color_func(alg_name),
            lw = 2,
        )

        axs[0, g].fill_between(
            df.index,
            df[f"error_accepted_g{g}"]["mean"] - df[f"error_accepted_g{g}"]["std"],
            df[f"error_accepted_g{g}"]["mean"] + df[f"error_accepted_g{g}"]["std"],
            alpha=0.2,
            color = color_func(alg_name),
        )

        axs[1, g].fill_between(
            df.index,
            df[f"renyi_div_g{g}"]["mean"] - df[f"renyi_div_g{g}"]["std"],
            df[f"renyi_div_g{g}"]["mean"] + df[f"renyi_div_g{g}"]["std"],
            alpha=0.2,
            color = color_func(alg_name),
        )

fig.subplots_adjust(bottom=0.3, wspace=0.33)

axs[1, 0].legend(
    loc="upper center",
    bbox_to_anchor=(1, -0.3),
    ncol=5,
    fontsize=12
)

groups_names = ["Unprivileged", "Privileged"]
for g in range(2):
    axs[0, g].set_title(f"{groups_names[g]} Group", fontsize=14)

axs[0, 0].set_ylabel("Error on rejected pop.", fontsize=12)
axs[1, 0].set_ylabel("Renyi Divergence", fontsize=12)


axs[0, 1].set_ylim(-0.02, 0.06)

fig.subplots_adjust(wspace=0.15)

plt.savefig("figures/bound_terms.pdf", bbox_inches="tight")

# %% [markdown]
# # Sec. 5 Experiments

# %% [markdown]
# ## FICO

# %%
env_name = "fico_equal"
mu_type = "tpr"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.37 ($\pm$ 0.01) 	 & 1626.14 ($\pm$ 13.2)
# POCAR 			 & 0.37 ($\pm$ 0.01) 	 & 1627.02 ($\pm$ 13.2)
# POCAR (Oracle) 		 & 0.05 ($\pm$ 0.01) 	 & 1158.04 ($\pm$ 12.1)
# SELLF 			 & 0.03 ($\pm$ 0.01) 	 & 1254.46 ($\pm$ 17.1)
# SELLF (Semi-stoc.) 		 & 0.05 ($\pm$ 0.01) 	 & 1294.82 ($\pm$ 15.2)
# ELBERT 		 & 0.3 ($\pm$ 0.01) 	 & 1629.62 ($\pm$ 13.3)
# FOCOPS 		 & 0.29 ($\pm$ 0.01) 	 & 1629.28 ($\pm$ 12.7)

# %%
print("Execution time (min):")
for alg in selected_algs:
    with open(f"experiments/{env_name}/{mu_type}/{alg}/models/train_time.txt") as f:
        print(f"{base_legend_func(alg)}: {float(f.read()):.2f}")
# Out:
# Execution time (min):
# SELLF: 15.79
# SELLF (Semi-stoc.): 15.63
# ELBERT: 13.65
# FOCOPS: 10.68
# POCAR: 7.75
# POCAR (Oracle): 7.39
# PPO: 7.34

# %%
env_name = "fico_equal"
mu_type = "tpr"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(6, 2.7), gridspec_kw={'width_ratios': [1, 1, 0.7]})

df_list = [
    pd.read_csv(f"experiments/{env_name}/{mu_type}/{alg}/eval/eval_data.csv")
    for alg in selected_algs
]

# first, let's calculate the accept rate of each alg
accept_rate_g0 = {}
accept_rate_g1 = {}

for i in range(len(df_list)):
    df_list[i]["accept_and_g0"] = df_list[i]["action"] * (df_list[i]["group_id"] == 0)
    df_list[i]["accept_and_g1"] = df_list[i]["action"] * (df_list[i]["group_id"] == 1)
    df_list[i]["g0"] = (df_list[i]["group_id"] == 0)
    df_list[i]["g1"] = (df_list[i]["group_id"] == 1)
    accept_g0 = df_list[i].groupby("ep")["accept_and_g0"].sum()
    accept_g1 = df_list[i].groupby("ep")["accept_and_g1"].sum()

    n_g0 = df_list[i].groupby("ep")["g0"].sum()
    n_g1 = df_list[i].groupby("ep")["g1"].sum()

    accept_rate_g0[selected_algs[i]] = {
        "mean": (accept_g0 / n_g0).mean(),
        "std": (accept_g0 / n_g0).std(),
    }
    accept_rate_g1[selected_algs[i]] = {
        "mean": (accept_g1 / n_g1).mean(),
        "std": (accept_g1 / n_g1).std(),
    }

    df_list[i]["delta"] = df_list[i]["delta"].abs()

    df_list[i] = (
        df_list[i]
        .groupby("t")
        .agg(
            {
                "resource": ["mean", "std"],
                "delta": ["mean", "std"],
            }
        )
    )

for alg, df in zip(selected_algs, df_list):
    

    axs[0].plot(
        df.index,
        df["resource"]["mean"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        linestyle="--" if "full" in alg else "-",
        zorder = get_zorder(alg),
    )
    axs[0].fill_between(
        df.index,
        df["resource"]["mean"] - df["resource"]["std"],
        df["resource"]["mean"] + df["resource"]["std"],
        alpha=0.3,
        color=base_color_func(alg),
        zorder = get_zorder(alg),
    )

    axs[1].plot(
        df.index,
        df["delta"]["mean"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        linestyle="--" if "full" in alg else "-",
        zorder = get_zorder(alg),
    )
    axs[1].fill_between(
        df.index,
        df["delta"]["mean"] - df["delta"]["std"],
        df["delta"]["mean"] + df["delta"]["std"],
        alpha=0.3,
        color=base_color_func(alg),
        zorder = get_zorder(alg),
    )

    # axs[2].plot(
    #     df.index,
    #     df["n_accept_g0"]["mean"],
    #     label=base_legend_func(alg),
    #     color=base_color_func(alg),
    #     linestyle="--" if "full" in alg else "-",
    #     lw=2,
    # )

    # axs[2].fill_between(
    #     df.index,
    #     df["n_accept_g0"]["mean"] - df["n_accept_g0"]["std"],
    #     df["n_accept_g0"]["mean"] + df["n_accept_g0"]["std"],
    #     alpha=0.3,
    #     color=base_color_func(alg),
    # )

    # scatter the acceptance rate
    #axs[2].scatter(
    #    [accept_rate_g0],
    #    [accept_rate_g1],
    #    label=base_legend_func(alg),
    #    color=base_color_func(alg),
    #    s=100,
    #)

    # scatter with error bars
    axs[2].errorbar(
        accept_rate_g0[alg]["mean"],
        accept_rate_g1[alg]["mean"],
        xerr=accept_rate_g0[alg]["std"],
        yerr=accept_rate_g1[alg]["std"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        fmt='o',
        markersize=8,
        capsize=5,
    )
        
for i in range(2):
    axs[i].set_xlabel("Timestep", fontsize = 12)

axs[2].set_xlabel("$P(A = 1 | Z = 0)$", fontsize = 12)
axs[2].set_ylabel("$P(A = 1 | Z = 1)$", fontsize = 12)
# place the y ticks of the last plot on the right
axs[2].yaxis.tick_right()
axs[2].yaxis.set_label_position("right")

axs[0].set_title("Cumulative Reward")
axs[1].set_title("Disparity $(|\Delta_t|)$")
axs[2].set_title("Accept rate")

# place legend outside bellow all plots
fig.subplots_adjust(bottom=0.3, wspace=0.33)

axs[1].legend(
    loc="upper center",
    bbox_to_anchor=(0.35, -0.3),
    ncol= 4, #len(selected_algs),
)

for i in range(3):
    axs[i].grid(True)

fig.subplots_adjust(wspace = 0.25)
plt.savefig("figures/fico_tpr.pdf", bbox_inches="tight", dpi=300)
plt.show()

# %% [markdown]
# ## COMPAS

# %%
env_name = "compas"
mu_type = "tpr"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full_v2",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.09 ($\pm$ 0.01) 	 & 998.61 ($\pm$ 2.4)
# POCAR 			 & 0.03 ($\pm$ 0.0) 	 & 998.72 ($\pm$ 1.8)
# SELLF 			 & 0.04 ($\pm$ 0.0) 	 & 999.29 ($\pm$ 1.6)
# SELLF (Semi-stoc.) 		 & 0.04 ($\pm$ 0.0) 	 & 994.8 ($\pm$ 3.1)
# ELBERT 		 & 0.45 ($\pm$ 0.01) 	 & 753.02 ($\pm$ 19.2)
# FOCOPS 		 & 0.0 ($\pm$ 0.0) 	 & 1000.0 ($\pm$ 0.0)

# %%
print("Execution time (min):")
for alg in selected_algs:
    with open(f"experiments/{env_name}/{mu_type}/{alg}/models/train_time.txt") as f:
        print(f"{base_legend_func(alg)}: {float(f.read()):.2f}")
# Out:
# Execution time (min):
# SELLF: 16.83
# SELLF (Semi-stoc.): 16.57
# ELBERT: 15.66
# FOCOPS: 9.32
# POCAR: 8.76
# PPO: 8.45

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# ## ENEM

# %%
env_name = "enem"
mu_type = "qualification"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
env_name = "enem"
mu_type = "qualification"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.18 ($\pm$ 0.02) 	 & 1221.32 ($\pm$ 24.6)
# POCAR 			 & 0.17 ($\pm$ 0.02) 	 & 1203.5 ($\pm$ 27.8)
# POCAR (Oracle) 		 & 0.15 ($\pm$ 0.02) 	 & 1111.12 ($\pm$ 27.3)
# SELLF 			 & 0.14 ($\pm$ 0.02) 	 & 1157.88 ($\pm$ 24.3)

# %%
env_name = "enem"
mu_type = "qualification"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.19 ($\pm$ 0.02) 	 & 1235.12 ($\pm$ 14.8)
# POCAR 			 & 0.17 ($\pm$ 0.02) 	 & 1203.5 ($\pm$ 27.8)
# POCAR (Oracle) 		 & 0.15 ($\pm$ 0.02) 	 & 1111.12 ($\pm$ 27.3)
# SELLF 			 & 0.17 ($\pm$ 0.02) 	 & 1188.2 ($\pm$ 13.0)

# %%
print("Execution time (min):")
for alg in selected_algs:
    with open(f"experiments/{env_name}/{mu_type}/{alg}/models/train_time.txt") as f:
        print(f"{base_legend_func(alg)}: {float(f.read()):.2f}")
# Out:
# Execution time (min):
# SELLF: 32.64
# POCAR: 18.41
# POCAR (Oracle): 16.80
# PPO: 13.64

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(6.5, 2.7))

df_list = [
    pd.read_csv(f"experiments/{env_name}/{mu_type}/{alg}/eval/eval_data.csv")
    for alg in selected_algs
]

for i in range(len(df_list)):
    df_list[i]["accept_g0"] = df_list[i]["action"] * (df_list[i]["group_id"] == 0)
    df_list[i]["accept_g1"] = df_list[i]["action"] * (df_list[i]["group_id"] == 1)

    # for each ep, compute cumulative sum of accept_g0 and accept_g1
    df_list[i]["n_accept_g0"] = df_list[i].groupby("ep")["accept_g0"].cumsum()
    df_list[i]["n_accept_g1"] = df_list[i].groupby("ep")["accept_g1"].cumsum()

    # for each ep, calculate a rolling window of label with window 50
    df_list[i]["label"] = (
        df_list[i]
        .groupby("ep")["label"]
        .rolling(window=500, min_periods=30)
        .mean()
        .reset_index(0, drop=True)
    )

    df_list[i]["delta"] = df_list[i]["delta"].abs()

    df_list[i] = (
        df_list[i]
        .groupby("t")
        .agg(
            {
                "resource": ["mean", "std"],
                "delta": ["mean", "std"],
                "n_accept_g0": ["mean", "std"],
                "n_accept_g1": ["mean", "std"],
                "label": ["mean", "std"],
            }
        )
    )


for alg, df in zip(selected_algs, df_list):
    axs[0].plot(
        df.index,
        df["resource"]["mean"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        linestyle="--" if "full" in alg else "-",
        zorder = get_zorder(alg)
    )
    axs[0].fill_between(
        df.index,
        df["resource"]["mean"] - df["resource"]["std"],
        df["resource"]["mean"] + df["resource"]["std"],
        alpha=0.3,
        color=base_color_func(alg),
        zorder = get_zorder(alg)
    )

    axs[1].plot(
        df.index,
        df["delta"]["mean"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        linestyle="--" if "full" in alg else "-",
        zorder = get_zorder(alg),
    )
    axs[1].fill_between(
        df.index,
        df["delta"]["mean"] - df["delta"]["std"],
        df["delta"]["mean"] + df["delta"]["std"],
        alpha=0.3,
        color=base_color_func(alg),
        zorder =  get_zorder(alg),
    )

    axs[2].plot(
        df.index,
        df["label"]["mean"],
        label=base_legend_func(alg),
        color=base_color_func(alg),
        linestyle="--" if "full" in alg else "-",
        lw=2,
        zorder =  get_zorder(alg),
    )
    axs[2].fill_between(
        df.index,
        df["label"]["mean"] - df["label"]["std"],
        df["label"]["mean"] + df["label"]["std"],
        alpha=0.3,
        color=base_color_func(alg),
        zorder = get_zorder(alg),
    )

for i in range(3):
    axs[i].set_xlabel("Timestep")

axs[0].set_title("Cumulative Reward", fontsize = 12)
axs[1].set_title("Disparity ($|\Delta_t|$)", fontsize = 12)
axs[2].set_title("$P(Y = 1 | Z = $unprivileged)", fontsize = 12)

# place legend outside bellow all plots
fig.subplots_adjust(bottom=0.3, wspace=0.33)

axs[1].legend(
    loc="upper center",
    bbox_to_anchor=(0.35, -0.3),
    ncol=4 #len(selected_algs),
)

for i in range(3):
    axs[i].grid(True)
# make y ticks of last plot on the right

fig.subplots_adjust(wspace = 0.35)
plt.savefig("figures/enem_qualification.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Appendix

# %%
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]

# %% [markdown]
# ## FICO

# %% [markdown]
# ### Accuracy

# %%
env_name = "fico_equal"
mu_type = "accuracy"
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum([get_alg_names(alg) for alg in method_names], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())


selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# ### Qualification parity

# %%
env_name = "fico_equal"
mu_type = "qualification"
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum([get_alg_names(alg) for alg in method_names], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())


selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# ## COMPAS

# %% [markdown]
# ### Equal opportunity

# %%
env_name = "compas"
mu_type = "tpr"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
results[results.alg.isin(selected_algs)]

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# ### Qualification

# %%
env_name = "compas"
mu_type = "qualification"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# # ENEM

# %% [markdown]
# ### Equality of opportunity

# %%
env_name = "enem"
mu_type = "tpr"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# ### Accuracy

# %%
env_name = "enem"
mu_type = "accuracy"
alg_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum(
    [get_alg_names(alg) for alg in alg_names],
    [],
)
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()
    .reset_index()
)

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %% [markdown]
# # Deep predictor model

# %%
env_name = "fico_equal"
mu_type = "tpr"
alg_names = sum([get_alg_names(alg) for alg in ["sellf", "sellf_deep", "ppo"]], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()["alg"]
    .tolist()
)

# place sellf first
sellf_alg = [alg for alg in selected_algs if "sellf" in alg][0]
selected_algs.remove(sellf_alg)
selected_algs = [sellf_alg] + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, "figures/fico_tpr_deep.pdf")

# %%
env_name = "enem"
mu_type = "qualification"
alg_names = sum([get_alg_names(alg) for alg in ["sellf", "sellf_deep", "ppo"]], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first())

selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()["alg"]
    .tolist()
)

# place sellf first
sellf_alg = [alg for alg in selected_algs if "sellf" in alg][0]
selected_algs.remove(sellf_alg)
selected_algs = [sellf_alg] + selected_algs

# %%
base_plot(selected_algs, env_name, mu_type, "figures/enem_qualification_deep.pdf")

# %% [markdown]
# ## ENEM with continuous variables

# %%
env_name = "enemc"
mu_type = "tpr"
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum([get_alg_names(alg) for alg in method_names], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())


selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.15 ($\pm$ 0.02) 	 & 1338.58 ($\pm$ 14.9)
# POCAR 			 & 0.15 ($\pm$ 0.02) 	 & 1339.58 ($\pm$ 15.0)
# POCAR (Oracle) 		 & 0.06 ($\pm$ 0.02) 	 & 1259.46 ($\pm$ 17.3)
# SELLF 			 & 0.03 ($\pm$ 0.01) 	 & 1242.44 ($\pm$ 23.2)
# SELLF (Semi-stoc.) 		 & 0.05 ($\pm$ 0.02) 	 & 1279.22 ($\pm$ 20.2)
# ELBERT 		 & 0.18 ($\pm$ 0.02) 	 & 1339.58 ($\pm$ 15.0)
# FOCOPS 		 & 0.12 ($\pm$ 0.02) 	 & 1353.64 ($\pm$ 18.1)

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %%
env_name = "enemc"
mu_type = "accuracy"
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum([get_alg_names(alg) for alg in method_names], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())


selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.03 ($\pm$ 0.01) 	 & 1338.58 ($\pm$ 14.9)
# POCAR 			 & 0.03 ($\pm$ 0.01) 	 & 1328.24 ($\pm$ 15.0)
# POCAR (Oracle) 		 & 0.02 ($\pm$ 0.01) 	 & 1338.92 ($\pm$ 15.9)
# SELLF 			 & 0.03 ($\pm$ 0.01) 	 & 1330.5 ($\pm$ 18.0)
# SELLF (Semi-stoc.) 		 & 0.04 ($\pm$ 0.01) 	 & 1313.18 ($\pm$ 19.4)
# ELBERT 		 & 0.03 ($\pm$ 0.01) 	 & 1339.58 ($\pm$ 15.0)
# FOCOPS 		 & 0.05 ($\pm$ 0.01) 	 & 1351.56 ($\pm$ 19.4)

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %%
env_name = "enemc"
mu_type = "qualification"
method_names = [
    "ppo",
    "pocar",
    "pocar_full",
    "sellf",
    "sellf_censored_25",
    "elbert",
    "focops",
]
alg_names = sum([get_alg_names(alg) for alg in method_names], [])
results = summarize_hyperparam(env_name, mu_type, alg_names)
process_table(results.sort_values("score", ascending=False).groupby("alg_simplified").first().reset_index())


selected_algs = (
    results.sort_values("score", ascending=False)
    .groupby("alg_simplified")
    .first()['alg']
    .tolist()
)

# place sellf first
sellf_algs = [alg for alg in selected_algs if "sellf" in alg]
selected_algs = [alg for alg in selected_algs if "sellf" not in alg]
selected_algs = sellf_algs + selected_algs
# Out:
# alg 			 delta 			 reward
# PPO 			 & 0.16 ($\pm$ 0.02) 	 & 1327.08 ($\pm$ 18.4)
# POCAR 			 & 0.16 ($\pm$ 0.02) 	 & 1311.18 ($\pm$ 19.3)
# POCAR (Oracle) 		 & 0.14 ($\pm$ 0.02) 	 & 1107.48 ($\pm$ 17.7)
# SELLF 			 & 0.13 ($\pm$ 0.02) 	 & 1150.32 ($\pm$ 18.5)
# SELLF (Semi-stoc.) 		 & 0.13 ($\pm$ 0.02) 	 & 1150.32 ($\pm$ 18.5)
# ELBERT 		 & 0.16 ($\pm$ 0.02) 	 & 1337.88 ($\pm$ 20.6)
# FOCOPS 		 & 0.16 ($\pm$ 0.02) 	 & 1341.86 ($\pm$ 18.5)

# %%
base_plot(selected_algs, env_name, mu_type, f"figures/{env_name}_{mu_type}.pdf")

# %%
print("Execution time (min):")
for alg in selected_algs:
    with open(f"experiments/{env_name}/{mu_type}/{alg}/models/train_time.txt") as f:
        print(f"{base_legend_func(alg)}: {float(f.read()):.2f}")
# Out:
# Execution time (min):
# SELLF: 22.40
# SELLF (Semi-stoc.): 21.93
# ELBERT: 22.64
# FOCOPS: 12.13
# POCAR: 13.14
# POCAR (Oracle): 12.72
# PPO: 12.76
